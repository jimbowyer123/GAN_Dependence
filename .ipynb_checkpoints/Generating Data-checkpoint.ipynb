# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_x = np.random.normal(0,1,size=(100000,100))

dependent_data_y=2*data_x

independent_data_y=np.random.normal(0,4,size=(100000,100))

# %%
np.save('C:/Users/Jimbowyer123/Documents/GitHub/GAN_Dependence/Data/X_data',data_x)

# %%
np.save('C:/Users/Jimbowyer123/Documents/GitHub/GAN_Dependence/Data/Y_dependent',dependent_data_y)

# %%
np.save('C:/Users/Jimbowyer123/Documents/GitHub/GAN_Dependence/Data/Y_independent',independent_data_y)
